# %% [markdown]
# <a href="https://colab.research.google.com/github/RA2112704010029/APPLIED-DEEP-LEARNING-/blob/main/SparseAutoencoder.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# A. MSE CODE

# %%
# !pip install kagglehub

# %%
import os
import numpy as np
import cv2
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, Conv2DTranspose, Flatten, Dense, Reshape
from tensorflow.keras.models import Model
import matplotlib.pyplot as plt
import kagglehub

# Download dataset
path = kagglehub.dataset_download("canerbaloglu/ship-images-dataset")
print("Path to dataset files:", path)

# Load images
image_size = (128, 128)
valid_extensions = (".jpg", ".jpeg", ".png")
image_paths = []

if os.path.exists(path):
    for root, _, files in os.walk(path):
        for file in files:
            if file.lower().endswith(valid_extensions):
                image_paths.append(os.path.join(root, file))

# Reduce dataset size
num_images = 500  # Change this value to control the number of images used
image_paths = image_paths[:num_images]

def load_images(image_paths, size):
    images = []
    for img_path in image_paths:
        img = cv2.imread(img_path)
        if img is None:
            continue  # Skip if image is not loaded
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # Convert to RGB
        img = cv2.resize(img, size)
        img = img / 255.0  # Normalize to [0,1]
        images.append(img)
    images = np.array(images, dtype=np.float32)
    print(f"Loaded {len(images)} images with shape {images.shape}")
    return images

X = load_images(image_paths, image_size)

if len(X) == 0:
    raise ValueError("No valid image files found. Check dataset structure and ensure files are accessible.")

# Define vanilla autoencoder
input_shape = (128, 128, 3)
input_img = Input(shape=input_shape)

# Encoder
x = Conv2D(32, (3, 3), activation='relu', padding='same')(input_img)
x = Conv2D(64, (3, 3), activation='relu', padding='same', strides=(2, 2))(x)
x = Conv2D(128, (3, 3), activation='relu', padding='same', strides=(2, 2))(x)
x = Flatten()(x)
x = Dense(256, activation='relu')(x)
encoded = Dense(128, activation='relu')(x)  # Changed latent dimension to 64

# Decoder
d = Dense(256, activation='relu')(encoded)
d = Dense(32 * 32 * 128, activation='relu')(d)
d = Reshape((32, 32, 128))(d)
d = Conv2DTranspose(64, (3, 3), activation='relu', padding='same', strides=(2, 2))(d)
d = Conv2DTranspose(32, (3, 3), activation='relu', padding='same', strides=(2, 2))(d)
decoded = Conv2DTranspose(3, (3, 3), activation='sigmoid', padding='same')(d)

# Autoencoder model
autoencoder = Model(input_img, decoded)
autoencoder.compile(optimizer='adam', loss='mse')

autoencoder.summary()

# Ensure dataset is correctly shaped
if len(X.shape) != 4 or X.shape[1:] != (128, 128, 3):
    raise ValueError(f"Incorrect dataset shape: {X.shape}. Expected (num_samples, 128, 128, 3)")

# Train vanilla autoencoder
X_train = X[:int(0.8 * len(X))]
X_val = X[int(0.8 * len(X)):]

autoencoder.fit(X_train, X_train, validation_data=(X_val, X_val), epochs=20, batch_size=16)

# Display reconstructed images
def display_images(original, reconstructed, n=5):
    plt.figure(figsize=(10, 6))
    for i in range(n):
        # Original
        plt.subplot(2, n, i + 1)
        plt.imshow(original[i])
        plt.axis('off')

        # Reconstructed
        plt.subplot(2, n, i + 1 + n)
        plt.imshow(np.clip(reconstructed[i], 0., 1.))  # Ensure valid range
        plt.axis('off')
    plt.show()

reconstructed_imgs = autoencoder.predict(X_val[:5])
display_images(X_val[:5], reconstructed_imgs)
# Out:
# ...
# 100%|██████████| 75.9M/75.9M [00:00<00:00, 169MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/canerbaloglu/ship-images-dataset/versions/1
# Loaded 500 images with shape (500, 128, 128, 3)
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 128, 128, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d (Conv2D)                      │ (None, 128, 128, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 64, 64, 64)          │          18,496 │
# ...

# %% [markdown]
# B. USING KL DIVEREGENCE

# %%
import os
import numpy as np
import cv2
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, Conv2DTranspose, Flatten, Dense, Reshape
from tensorflow.keras.models import Model
import matplotlib.pyplot as plt
import kagglehub

# Download dataset
path = kagglehub.dataset_download("canerbaloglu/ship-images-dataset")
print("Path to dataset files:", path)

# Load images
image_size = (128, 128)
valid_extensions = (".jpg", ".jpeg", ".png")
image_paths = []

if os.path.exists(path):
    for root, _, files in os.walk(path):
        for file in files:
            if file.lower().endswith(valid_extensions):
                image_paths.append(os.path.join(root, file))

# Reduce dataset size
num_images = 500  # Change this value to control the number of images used
image_paths = image_paths[:num_images]

def load_images(image_paths, size):
    images = []
    for img_path in image_paths:
        img = cv2.imread(img_path)
        if img is None:
            continue  # Skip if image is not loaded
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # Convert to RGB
        img = cv2.resize(img, size)
        img = img / 255.0  # Normalize to [0,1]
        images.append(img)
    images = np.array(images, dtype=np.float32)
    print(f"Loaded {len(images)} images with shape {images.shape}")
    return images

X = load_images(image_paths, image_size)

if len(X) == 0:
    raise ValueError("No valid image files found. Check dataset structure and ensure files are accessible.")

# Define vanilla autoencoder
input_shape = (128, 128, 3)
input_img = Input(shape=input_shape)

# Encoder
x = Conv2D(32, (3, 3), activation='relu', padding='same')(input_img)
x = Conv2D(64, (3, 3), activation='relu', padding='same', strides=(2, 2))(x)
x = Conv2D(128, (3, 3), activation='relu', padding='same', strides=(2, 2))(x)
x = Flatten()(x)
x = Dense(256, activation='relu')(x)
encoded = Dense(128, activation='relu')(x)  # Changed latent dimension to 128

# Decoder
d = Dense(256, activation='relu')(encoded)
d = Dense(32 * 32 * 128, activation='relu')(d)
d = Reshape((32, 32, 128))(d)
d = Conv2DTranspose(64, (3, 3), activation='relu', padding='same', strides=(2, 2))(d)
d = Conv2DTranspose(32, (3, 3), activation='relu', padding='same', strides=(2, 2))(d)
d = Conv2DTranspose(3, (3, 3), activation='sigmoid', padding='same')(d)
decoded = Reshape((128, 128, 3))(d)

# Autoencoder model
autoencoder = Model(input_img, decoded)
autoencoder.compile(optimizer='adam', loss=tf.keras.losses.KLDivergence())

autoencoder.summary()

# Ensure dataset is correctly shaped
if len(X.shape) != 4 or X.shape[1:] != (128, 128, 3):
    raise ValueError(f"Incorrect dataset shape: {X.shape}. Expected (num_samples, 128, 128, 3)")

# Train vanilla autoencoder
X_train = X[:int(0.8 * len(X))]
X_val = X[int(0.8 * len(X)):]

autoencoder.fit(X_train, X_train, validation_data=(X_val, X_val), epochs=20, batch_size=16)

# Display original and reconstructed images
def display_images(original, reconstructed, n=5):
    plt.figure(figsize=(10, 6))
    for i in range(n):
        # Original
        plt.subplot(2, n, i + 1)
        plt.imshow(original[i])
        plt.title("Original")
        plt.axis('off')

        # Reconstructed
        plt.subplot(2, n, i + 1 + n)
        plt.imshow(np.clip(reconstructed[i], 0., 1.))  # Ensure valid range
        plt.title("Reconstructed")
        plt.axis('off')
    plt.show()

reconstructed_imgs = autoencoder.predict(X_val[:5])
display_images(X_val[:5], reconstructed_imgs)
# Out:
# Path to dataset files: /root/.cache/kagglehub/datasets/canerbaloglu/ship-images-dataset/versions/1
# Loaded 500 images with shape (500, 128, 128, 3)
# Model: "functional_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_5 (InputLayer)           │ (None, 128, 128, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_19 (Conv2D)                   │ (None, 128, 128, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_20 (Conv2D)                   │ (None, 64, 64, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# ...

# %%
#@title Convert ipynb to HTML in Colab
# Upload ipynb
from google.colab import files
f = files.upload()

# Convert ipynb to html
import subprocess
file0 = list(f.keys())[0]
_ = subprocess.run(["pip", "install", "nbconvert"])
_ = subprocess.run(["jupyter", "nbconvert", file0, "--to", "html"])

# download the html
files.download(file0[:-5]+"html")
# Out:
#      <input type="file" id="files-a04deb64-e1c0-4a17-acb7-0c8e8e33482a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a04deb64-e1c0-4a17-acb7-0c8e8e33482a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
